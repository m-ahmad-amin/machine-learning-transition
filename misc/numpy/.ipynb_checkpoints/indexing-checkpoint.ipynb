# %%
import numpy as np

# %%
arr = np.array([3, 8, 2, 9, 5, 7, 1])

# %%
arr
# Out:
# array([ 3,  8,  2, 10,  5,  7,  1])

# %%
np.where(arr > 5, 0, np.nan)
# Out:
# array([nan,  0., nan,  0., nan,  0., nan])

# %%
arr[[0, 2]]
# Out:
# array([3, 2])

# %%
arr[[1, 0]]
# Out:
# array([8, 3])

# %%
arr[[True, True, True, False, False, True, False]]
# Out:
# array([3, 8, 2, 7])

# %%
np.where(arr == 5, 1, 0)
# Out:
# array([0, 0, 0, 0, 1, 0, 0])
