# %%
import pandas as pd

# %%
ages = pd.Series([
    34, 28, 36, 45, 27, 27, 45, 37, 25, 35,
    25, 25, 32, 10, 12, 24, 19, 33, 20, 15,
    44, 27, 30, 15, 24, 31, 18, 33, 23, 27,
    23, 48, 29, 19, 38, 17, 32, 10, 16, 31,
    37, 31, 28, 26, 15, 22, 25, 40, 33, 12,
    33, 26, 23, 36, 40, 39, 21, 26, 33, 39,
    25, 28, 18, 18, 38, 43, 29, 40, 33, 23,
    33, 45, 29, 45, 3, 38, 30, 27, 30, 10,
    27, 33, 44, 24, 21, 24, 39, 33, 24, 35,
    30, 39, 22, 26, 26, 15, 32, 32, 30, 27
])

# %%
ages.head()
# Out:
# 0    34
# 1    28
# 2    36
# 3    45
# 4    27
# dtype: int64

# %%
ages.max()
# Out:
# 48

# %%
binned_ages = pd.cut(ages, bins=[0, 18, 40, 60], labels=['child', 'adult', 'senior'])

# %%
binned_ages.head()
# Out:
# 0     adult
# 1     adult
# 2     adult
# 3    senior
# 4     adult
# dtype: category
# Categories (3, object): ['child' < 'adult' < 'senior']

# %%
binned_ages.value_counts()
# Out:
# adult     77
# child     15
# senior     8
# Name: count, dtype: int64
