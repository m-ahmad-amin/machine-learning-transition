# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'Color': ['Red', 'Blue', 'Green', 'Red'],
    'Size': ['small', 'large', 'large', 'large']
})

# %%
df
# Out:
#    Color   Size
# 0    Red  small
# 1   Blue  large
# 2  Green  large
# 3    Red  large

# %%
df['Color'].value_counts()
# Out:
# Color
# Red      2
# Blue     1
# Green    1
# Name: count, dtype: int64

# %%
pd.get_dummies(df)
# Out:
#    Score  Color_Blue  Color_Green  Color_Red  Size_large  Size_small
# 0      1       False        False       True       False        True
# 1      3        True        False      False        True       False
# 2      4       False         True      False        True       False
# 3      6       False        False       True        True       False

# %%
pd.get_dummies(df, columns=['Color'])
# Out:
#     Size  Color_Blue  Color_Green  Color_Red
# 0  small       False        False       True
# 1  large        True        False      False
# 2  large       False         True      False
# 3  large       False        False       True

# %%
pd.get_dummies(df, columns=['Color'], drop_first=True)
# Out:
#     Size  Color_Green  Color_Red
# 0  small        False       True
# 1  large        False      False
# 2  large         True      False
# 3  large        False       True
