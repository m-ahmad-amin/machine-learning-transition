# %%
import pandas as pd

df = pd.DataFrame({
    "Gender": [
        "Male", "Male", "Male", "Male", "Male",
        "Female", "Female", "Female", "Female", "Female"
    ],
    "Salary": [
        50000, 55000, 60000, 65000, 70000,
        45000, 48000, 52000, 58000, 62000
    ]
})

# %%
df
# Out:
#    Gender  Salary
# 0    Male   50000
# 1    Male   55000
# 2    Male   60000
# 3    Male   65000
# 4    Male   70000
# 5  Female   45000
# 6  Female   48000
# 7  Female   52000
# 8  Female   58000
# 9  Female   62000

# %%
import seaborn as sns

# %%
sns.boxplot(data=df, y='Salary', x='Gender')
# Out:
# <Axes: xlabel='Gender', ylabel='Salary'>
