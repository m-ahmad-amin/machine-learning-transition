# %%
import pandas as pd

df = pd.DataFrame({
    "Gender": ["Male", "Male", "Male", "Female", "Female", "Female"],
    "Salary": [50000, 60000, 70000, 45000, 55000, 90000]
})

# %%
df
# Out:
#    Gender  Salary
# 0    Male   50000
# 1    Male   60000
# 2    Male   70000
# 3  Female   45000
# 4  Female   55000
# 5  Female   90000

# %%
import seaborn as sns

# %%
sns.boxplot(data=df, x='Salary')
# Out:
# <Axes: xlabel='Salary'>
